# %%
import sqlite3
import numpy
import matplotlib.pyplot as plt


import pandas as pd
import requests

# %%
nypd_df = pd.read_csv("/home/student/PythonDeveloper/pythonProject/Projekt_Pandas/data/nypd-motor-vehicle-collisions.csv")#, usecols=["name", "ingredients"]
nypd_df
# Out:
#                 ACCIDENT DATE ACCIDENT TIME    BOROUGH  ZIP CODE   LATITUDE
# 0     2019-08-05T00:00:00.000         16:30     QUEENS   11434.0  40.676052  \
# 1     2019-08-27T00:00:00.000         16:02   BROOKLYN   11225.0  40.657780
# 2     2019-08-15T00:00:00.000         17:57  MANHATTAN   10002.0  40.718143
# 3     2019-08-30T00:00:00.000         21:53      BRONX   10460.0  40.840534
# 4     2019-08-06T00:00:00.000          9:45  MANHATTAN   10016.0  40.745440
# ...                       ...           ...        ...       ...        ...
# 4961  2019-08-03T00:00:00.000          1:00     QUEENS   11411.0  40.700030
# 4962  2019-08-05T00:00:00.000         11:00        NaN       NaN  40.665142
# 4963  2019-08-09T00:00:00.000         11:50     QUEENS   11379.0  40.721592
# 4964  2019-08-24T00:00:00.000          1:56     QUEENS   11420.0  40.671474
# 4965  2019-08-07T00:00:00.000         21:40        NaN       NaN  40.747080
#
# ...

# %%
nypd_df['ACCIDENT DATE'] = pd.to_datetime(nypd_df['ACCIDENT DATE'], errors='coerce')
nypd_df
# Out:
#      ACCIDENT DATE ACCIDENT TIME    BOROUGH  ZIP CODE   LATITUDE  LONGITUDE
# 0       2019-08-05         16:30     QUEENS   11434.0  40.676052 -73.790184  \
# 1       2019-08-27         16:02   BROOKLYN   11225.0  40.657780 -73.951096
# 2       2019-08-15         17:57  MANHATTAN   10002.0  40.718143 -73.993835
# 3       2019-08-30         21:53      BRONX   10460.0  40.840534 -73.866610
# 4       2019-08-06          9:45  MANHATTAN   10016.0  40.745440 -73.975400
# ...            ...           ...        ...       ...        ...        ...
# 4961    2019-08-03          1:00     QUEENS   11411.0  40.700030 -73.745895
# 4962    2019-08-05         11:00        NaN       NaN  40.665142 -73.996690
# 4963    2019-08-09         11:50     QUEENS   11379.0  40.721592 -73.876470
# 4964    2019-08-24          1:56     QUEENS   11420.0  40.671474 -73.815480
# 4965    2019-08-07         21:40        NaN       NaN  40.747080 -73.981350
#
#                                                LOCATION
# ...

# %%
nypd_days=nypd_df['ACCIDENT DATE'].dt.day_name()
nypd_days
# Out:
# 0          Monday
# 1         Tuesday
# 2        Thursday
# 3          Friday
# 4         Tuesday
#           ...
# 4961     Saturday
# 4962       Monday
# 4963       Friday
# 4964     Saturday
# 4965    Wednesday
# Name: ACCIDENT DATE, Length: 4966, dtype: object

# %%
nypd_numbers= nypd_days.value_counts()
nypd_numbers
# Out:
# ACCIDENT DATE
# Friday       844
# Saturday     739
# Thursday     735
# Wednesday    715
# Monday       674
# Tuesday      655
# Sunday       604
# Name: count, dtype: int64

# %%
df_nypd_numbers = pd.DataFrame(nypd_numbers)
df_nypd_numbers=df_nypd_numbers.reset_index()
df_nypd_numbers
# Out:
#   ACCIDENT DATE  count
# 0        Friday    844
# 1      Saturday    739
# 2      Thursday    735
# 3     Wednesday    715
# 4        Monday    674
# 5       Tuesday    655
# 6        Sunday    604

# %%
df_nypd_numbers = df_nypd_numbers.rename(columns={'ACCIDENT DATE': 'WEEK DAY','count':'AMOUNT' })
df_nypd_numbers
# Out:
#     WEEK DAY  AMOUNT
# 0     Friday     844
# 1   Saturday     739
# 2   Thursday     735
# 3  Wednesday     715
# 4     Monday     674
# 5    Tuesday     655
# 6     Sunday     604

# %%
#create bar plot to visualize sales by product
df_nypd_numbers_bar = df_nypd_numbers.plot.bar(x='WEEK DAY', y='AMOUNT',title='Ilość wypadków w danym dniu tygodnia', legend=False)

#annotate bars
df_nypd_numbers_bar.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '844'),
#  Text(0, 0, '739'),
#  Text(0, 0, '735'),
#  Text(0, 0, '715'),
#  Text(0, 0, '674'),
#  Text(0, 0, '655'),
#  Text(0, 0, '604')]
